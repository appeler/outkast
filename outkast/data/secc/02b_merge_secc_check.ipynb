# %%
import pandas as pd

# %%
df = pd.read_csv('/opt/data/secc/secc_state_name_age_sex_social_cat.csv.gz', usecols=['state'])

# %%
df.size
# Out:
# 420613593

# %%
df.groupby(['state']).size()
# Out:
# state
# arunachal pradesh     1189638
# assam                 7114232
# bihar                54197114
# chhattisgarh          8536248
# gujarat              20474063
# haryana               7928621
# kerala               17805905
# madhya pradesh       33788308
# maharashtra          41188662
# mizoram                120572
# nagaland               854973
# odisha               31567430
# punjab                8848364
# rajasthan            28359145
# sikkim                 266484
# tamilnadu            30675056
# uttar pradesh        74437606
# uttarakhand           4425566
# west bengal          48835606
# dtype: int64

# %%
df = pd.read_csv('/opt/data/secc/secc_state_name_age_sex_social_cat.csv.gz', usecols=['state', 'name', 'social_cat'])
df
# Out:
#                        state social_cat                    name
# 0          arunachal pradesh         st               jaflo mai
# 1          arunachal pradesh         st           jingroso tega
# 2          arunachal pradesh         st            thankha tega
# 3          arunachal pradesh         st             yatong tega
# 4          arunachal pradesh         st               bijoy mai
# 5          arunachal pradesh         st           dimongso tega
# 6          arunachal pradesh         st         grotho tabronyu
# 7          arunachal pradesh         st            kaflulum mai
# 8          arunachal pradesh         st          kamlingso tega
# 9          arunachal pradesh         st             namkho tega
# 10         arunachal pradesh         st                  r_tega
# 11         arunachal pradesh         st        talelum tabronyu
# 12         arunachal pradesh         st               jaflo mai
# 13         arunachal pradesh         st           jingroso tega
# ...

# %%
df.groupby(['social_cat']).size()
# Out:
# social_cat
# other    297501016
# sc        80649033
# st        42463544
# dtype: int64

# %%
df.describe()
# Out:
#                 state social_cat       name
# count       420613593  420613593  420566844
# unique             19          3   43992290
# top     uttar pradesh      other     ramesh
# freq         74437606  297501016     552077
